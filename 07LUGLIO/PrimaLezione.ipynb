# %%
print(2+2)
# Out:
# Running cells with '.venv (3.14.4.final.0) (Python 3.14.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/A1604apulia/Desktop/sviluppo/Machine Learning/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
